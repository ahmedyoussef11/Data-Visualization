# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()

import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

import seaborn as sns

# %%
fifa_file= pd.read_csv("C:\\Users\\HP\\Downloads\\fifa.csv", index_col="Date", parse_dates=True)
fifa_file
# Out:
#              ARG  BRA   ESP   FRA  GER   ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0
# ...          ...  ...   ...   ...  ...   ...
# 2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0
#
# [286 rows x 6 columns]

# %%
fifa_file.tail()
# Out:
#             ARG  BRA   ESP  FRA  GER   ITA
# Date
# 2018-02-15  4.0  2.0   6.0  9.0  1.0  14.0
# 2018-03-15  4.0  2.0   6.0  9.0  1.0  14.0
# 2018-04-12  5.0  2.0   8.0  7.0  1.0  20.0
# 2018-05-17  5.0  2.0   8.0  7.0  1.0  20.0
# 2018-06-07  5.0  2.0  10.0  7.0  1.0  19.0

# %% [markdown]
# # Plot the data

# %%
plt.figure(figsize= (15, 7))
sns.set_style('darkgrid')
sns.lineplot(data = fifa_file)
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.set_style('darkgrid')
sns.lineplot(fifa_file['ARG'], color = 'k')
plt.title('Argentina')
plt.xlabel('Date')
plt.show()

# %% [markdown]
# # Line Charts

# %%
spotify_data = pd.read_csv("C:\\Users\\HP\\Downloads\\spotify.csv")
spotify_data
# Out:
#            Date  Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# 0    2017-01-06      12287078        NaN                       NaN        NaN
# 1    2017-01-07      13190270        NaN                       NaN        NaN
# 2    2017-01-08      13099919        NaN                       NaN        NaN
# 3    2017-01-09      14506351        NaN                       NaN        NaN
# 4    2017-01-10      14275628        NaN                       NaN        NaN
# ..          ...           ...        ...                       ...        ...
# 361  2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 362  2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 363  2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 364  2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 365  2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#      Unforgettable
# ...

# %%
plt.figure(figsize=(14,6))

plt.title("Daily Global Streams of Popular Songs in 2017-2018")


sns.lineplot(data=spotify_data['Shape of You'], label="Shape of You")

sns.lineplot(data=spotify_data['Despacito'], label="Despacito")

plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# # Bar Charts

# %%
flight_path = "C:\\Users\\HP\\Downloads\\flight_delays.csv"
flight_data = pd.read_csv(flight_path, index_col = 'Month')
flight_data
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 6      8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 7      3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 8      3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 9     -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 10    -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 11     0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 12     4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %%
sns.barplot(x = flight_data.index, y = flight_data['NK'])
plt.title("Average Arrival Delay for Spirit Airlines Flights, by Month")
plt.ylabel("Arrival delay (in minutes)")
plt.show()

# %% [markdown]
# # Heatmaps

# %%
plt.figure(figsize=(14,7))
plt.title("Average Arrival Delay for Each Airline, by Month")
sns.heatmap(flight_data, annot = True, cmap = 'Blues')
plt.show()

# %% [markdown]
# # Scatter plot

# %%
insurance_data = pd.read_csv("C:\\Users\\HP\\Downloads\\insurance.csv")
insurance_data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
sns.scatterplot(x = insurance_data['bmi'], y = insurance_data['charges'], color = 'r')
plt.show()

# %%
sns.regplot(x = insurance_data['bmi'], y = insurance_data['charges'])
plt.show()

# %%
sns.scatterplot(x = insurance_data['bmi'], y = insurance_data['charges'], hue = insurance_data['smoker'])
plt.show()

# %%
sns.lmplot(data = insurance_data , x = 'bmi', y = 'charges', hue = 'smoker')
plt.show()

# %%
sns.swarmplot(x = insurance_data['smoker'], y = insurance_data['charges'])
plt.show()

# %% [markdown]
# # Histograms

# %%
iris_data = pd.read_csv("C:\\Users\\HP\\Downloads\\iris.csv", index_col = 'Id')
iris_data
# Out:
#      Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                  5.1               3.5                1.4               0.2
# 2                  4.9               3.0                1.4               0.2
# 3                  4.7               3.2                1.3               0.2
# 4                  4.6               3.1                1.5               0.2
# 5                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 146                6.7               3.0                5.2               2.3
# 147                6.3               2.5                5.0               1.9
# 148                6.5               3.0                5.2               2.0
# 149                6.2               3.4                5.4               2.3
# 150                5.9               3.0                5.1               1.8
#
#             Species
# Id
# ...

# %%
sns.histplot(iris_data['Petal Length (cm)'])
plt.show()

# %% [markdown]
# # kernel density estimate (KDE)

# %%
sns.kdeplot(data=iris_data['Petal Length (cm)'], shade=True)
plt.show()

# %% [markdown]
# # 2D KDE plots

# %%
sns.jointplot(x = iris_data['Petal Length (cm)'], y = iris_data['Sepal Width (cm)'], kind = 'kde')
plt.show()

# %% [markdown]
# # Color-coded plots

# %%
sns.histplot(data = iris_data, x = 'Petal Length (cm)', hue = 'Species')
plt.title("Histogram  of Petal Lengths, by Species")
plt.show()

# %%
sns.kdeplot(data=iris_data, x='Petal Length (cm)', hue='Species', shade=True)
plt.title("Distribution of Petal Lengths, by Species")
plt.show()

# %% [markdown]
# ![Ahmed_youssefff%20-%20Data%20Visualization.png](attachment:Ahmed_youssefff%20-%20Data%20Visualization.png)
